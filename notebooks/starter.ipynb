# %% [markdown]
# # Image Classification Starter Notebook
#
# Use this notebook to inspect data, test augmentations, and run quick experiments before full training.

# %%
from src.image_classification.config import Settings
from src.image_classification.data import build_datasets

settings = Settings()
train_ds, val_ds, class_names = build_datasets(settings)
class_names
